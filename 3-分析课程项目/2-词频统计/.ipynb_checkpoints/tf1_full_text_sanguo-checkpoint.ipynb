# %% [markdown]
# ## 本程序是基于jieba分词的全文本词频统计

# %% [markdown]
# ## 全文本词频统计的步骤
# + 打开文本
# + 分词
# + 去除停用词（集合的方式）
# + 利用字典，进行词-词频的存储
# + 排序
# + 展示（输出print）

# %%
import jieba

# %%
article = open('sanguo_10.txt','r',encoding = 'utf-8').read() # 打开并读取三国前10回 #出现乱码提示，就把ansi改成utf-8

# %%
dele = {'。','！','？','的','“','”','（','）',' ','》','《','，','曹操'} # 手动设计一些停用词和符号

# %%
jieba.add_word('贼') # 加入字典中没有的新词

# %%
words = list(jieba.cut(article)) #结巴分词出来的词汇

# %%
words
# Out:
# ['《',
#  '三国演义',
#  '》',
#  '（',
#  '全',
#  '）',
#  '\n',
#  '\n',
#  '（',
#  '明',
#  '）',
#  '羅',
#  '貫中著',
#  '\n',
#  '\n',
#  ' ',
#  ' ',
#  '\n',
#  '第一回',
#  '\n',
#  '宴桃園',
#  '豪傑',
#  '三',
#  '結義斬黃巾',
#  '英雄',
#  '首',
#  '立功',
#  '\n',
#  '話',
#  '說',
#  '天下',
#  '大勢',
#  '，',
#  '分久必合',
#  '，',
#  '合久必分',
#  '：',
#  '周末',
#  '七國',
#  '分爭',
#  '，',
#  '並',
#  '\n',
#  '入于',
#  '秦',
#  '；',
#  '及',
#  '秦滅',
#  '之',
#  '後',
#  '，',
#  '楚',
#  '、',
#  '漢分爭',
#  '，',
#  '又',
#  '並入',
#  '於',
#  '漢',
#  '；',
#  '漢朝',
#  '自',
#  '高祖',
#  '\n',
#  '斬',
#  '白蛇',
#  '而',
#  '起義',
#  '，',
#  '一統',
#  '天下',
#  '，',
#  '後',
#  '來光',
#  '武中興',
#  '，',
#  '傳至獻帝',
#  '，',
#  '遂',
#  '分',
#  '爲',
#  '\n',
#  '三國',
#  '。',
#  '推其致',
#  '亂',
#  '之',
#  '由',
#  '，',
#  '殆始',
#  '於',
#  '桓',
#  '、',
#  '靈',
#  '二帝',
#  '。',
#  '桓帝',
#  '禁錮',
#  '善類',
#  '，',
#  '崇',
#  '\n',
#  '信',
#  '宦官',
#  '。',
#  '及桓帝',
#  '崩',
#  '，',
#  '靈帝',
#  '即位',
#  '，',
#  '大將',
#  '軍',
#  '竇武',
#  '、',
#  '太傅',
#  '陳',
#  '蕃',
#  '，',
#  '共',
#  '相',
#  '\n',
#  '輔佐',
#  '。',
#  '時有',
#  '宦官',
#  '曹節',
#  '等',
#  '弄權',
#  '，',
#  '竇武',
#  '、',
#  '陳',
#  '蕃',
#  '謀',
#  '誅',
#  '之',
#  '，',
#  '機事',
#  '不密',
#  '，',
#  '\n',
#  '反',
#  '爲',
#  '所害',
#  '。',
#  '中',
#  '涓',
#  '自此',
#  '愈橫',
#  '。',
#  '\n',
#  '建寧',
#  '二年',
#  '四月',
#  '望',
#  '日',
#  '，',
#  '帝禦',
#  '溫德殿',
#  '。',
#  '方',
#  '升座',
#  '，',
#  '殿角',
#  '狂風驟',
#  '起',
#  '，',
#  '\n',
#  '只見',
#  '一條',
#  '大',
#  '青蛇',
#  '，',
#  '從',
#  '梁上',
#  '飛將',
#  '下來',
#  '，',
#  '蟠',
#  '於',
#  '椅上',
#  '。',
#  '帝驚',
#  '倒',
#  '，',
#  '左右',
#  '\n',
#  '急救',
#  '入宮',
#  '，',
#  '百官',
#  '俱奔避',
#  '。',
#  '須臾',
#  '，',
#  '蛇',
#  '不見',
#  '了',
#  '；',
#  '忽然',
#  '大雷',
#  '大雨',
#  '，',
#  '加',
#  '\n',
#  '以',
#  '冰雹',
#  '，',
#  '落到',
#  '半夜',
#  '方止',
#  '，',
#  '壞',
#  '卻',
#  '房屋',
#  '無數',
#  '。',
#  '建寧',
#  '四年',
#  '二月',
#  '，',
#  '洛陽',
#  '\n',
#  '地震',
#  '；',
#  '又',
#  '海水',
#  '泛溢',
#  '，',
#  '沿海居民',
#  '，',
#  '盡',
#  '被',
#  '大浪',
#  '捲',
#  '入海',
#  '中',
#  '。',
#  '光',
#  '和',
#  '元年',
#  '，',
#  '\n',
#  '雌雞化雄',
#  '。',
#  '六月',
#  '朔',
#  '，',
#  '黑氣',
#  '十餘丈',
#  '，',
#  '飛入',
#  '溫德殿',
#  '中',
#  '。',
#  '秋',
#  '七月',
#  '，',
#  '有',
#  '\n',
#  '虹現',
#  '於',
#  '玉堂',
#  '，',
#  '五原',
#  '山岸',
#  '盡',
#  '皆',
#  '崩裂',
#  '。',
#  '種種',
#  '不祥',
#  '，',
#  '非止',
#  '一端',
#  '。',
#  '帝下',
#  '\n',
#  '詔問',
#  '群臣',
#  '以災異',
#  '之',
#  '由',
#  '。',
#  '議',
#  '郎蔡邕',
#  '上',
#  '疏',
#  '，',
#  '以',
#  '爲',
#  '蜺',
#  '墮',
#  '、',
#  '雞化',
#  '，',
#  '乃婦',
#  '\n',
#  '寺',
#  '幹政',
#  '之',
#  '所致',
#  '，',
#  '言',
#  '頗',
#  '切直',
#  '。',
#  '帝覽',
#  '奏',
#  '歎',
#  '息',
#  '，',
#  '因起',
#  '更衣',
#  '。',
#  '曹節',
#  '在',
#  '後',
#  '\n',
#  '竊視',
#  '，',
#  '悉',
#  '宣告',
#  '左右',
#  '；',
#  '遂',
#  '以',
#  '他',
#  '事',
#  '陷邕',
#  '於',
#  '罪',
#  '，',
#  '放歸田',
#  '裏',
#  '。',
#  '後',
#  '張',
#  '讓',
#  '、',
#  '\n',
#  '趙',
#  '忠',
#  '、',
#  '封諝',
#  '、',
#  '段',
#  '珪',
#  '、',
#  '曹節',
#  '、',
#  '侯覽',
#  '、',
#  '蹇',
#  '碩',
#  '、',
#  '程曠',
#  '、',
#  '夏惲',
#  '、',
#  '郭勝十',
#  '\n',
#  '人朋比',
#  '爲',
#  '奸',
#  '，',
#  '號',
#  '爲',
#  '“',
#  '十常侍',
#  '”',
#  '。',
#  '帝尊',
#  '信張',
#  '讓',
#  '，',
#  '呼',
#  '爲',
#  '“',
#  '阿父',
#  '”',
#  '。',
#  '\n',
#  ' ',
#  ' ',
#  '\n',
#  '朝政',
#  '日非',
#  '，',
#  '以致',
#  '天下人',
#  '心思',
#  '亂',
#  '，',
#  '盜賊',
#  '蜂起',
#  '。',
#  '\n',
#  '時',
#  '巨鹿郡',
#  '有',
#  '兄弟',
#  '三人',
#  '：',
#  '一名',
#  '張角',
#  '，',
#  '一名',
#  '張寶',
#  '，',
#  '一名',
#  '張梁',
#  '。',
#  '\n',
#  '那',
#  '張角本',
#  '是',
#  '個',
#  '不',
#  '第',
#  '秀才',
#  '，',
#  '因入',
#  '山',
#  '采藥',
#  '，',
#  '遇一',
#  '老人',
#  '，',
#  '碧眼',
#  '童',
#  '顔',
#  '，',
#  '\n',
#  '手',
#  '執藜',
#  '杖',
#  '，',
#  '喚角',
#  '至',
#  '一洞',
#  '中',
#  '，',
#  '以天書',
#  '三卷',
#  '授',
#  '之',
#  '，',
#  '曰',
#  '：',
#  '“',
#  '此名',
#  '《',
#  '太',
#  '\n',
#  '平要術',
#  '》',
#  '。',
#  '汝得',
#  '之',
#  '，',
#  '當代天',
#  '宣化',
#  '，',
#  '普',
#  '救世',
#  '人',
#  '。',
#  '若萌',
#  '異心',
#  '，',
#  '必獲',
#  '\n',
#  '惡報',
#  '。',
#  '”',
#  '角拜問',
#  '姓名',
#  '。',
#  '老人',
#  '曰',
#  '：',
#  '“',
#  '吾',
#  '乃',
#  '南華',
#  '老仙',
#  '也',
#  '。',
#  '”',
#  '言',
#  '訖',
#  '，',
#  '\n',
#  '化陣',
#  '清風',
#  '而',
#  '去',
#  '。',
#  '角得',
#  '此書',
#  '，',
#  '曉夜',
#  '攻習',
#  '，',
#  '能呼',
#  '風喚',
#  '雨',
#  '，',
#  '號',
#  '爲',
#  '“',
#  '太',
#  '\n',
#  '平道人',
#  '”',
#  '。',
#  '\n',
#  '中平',
#  '元年',
#  '正月',
#  '內',
#  '，',
#  '疫氣',
#  '流行',
#  '，',
#  '張角',
#  '散施',
#  '符水',
#  '，',
#  '爲',
#  '人',
#  '治病',
#  '，',
#  '\n',
#  '自稱',
#  '“',
#  '大賢良師',
#  '”',
#  '。',
#  '角有',
#  '徒弟',
#  '五百余',
#  '人',
#  '，',
#  '雲遊',
#  '四方',
#  '，',
#  '皆',
#  '能書符',
#  '\n',
#  '念咒',
#  '。',
#  '次後徒',
#  '衆',
#  '日',
#  '多',
#  '，',
#  '角乃立',
#  '三十六方',
#  '，',
#  '大方',
#  '萬餘人',
#  '，',
#  '小方',
#  '六',
#  '\n',
#  '七千',
#  '，',
#  '各立',
#  '渠帥',
#  '，',
#  '稱',
#  '爲',
#  '將軍',
#  '；',
#  '訛言',
#  '：',
#  '“',
#  '蒼天',
#  '已',
#  '死',
#  '，',
#  '黃',
#  '天當立',
#  '；',
#  '\n',
#  '歲',
#  '在',
#  '甲子',
#  '，',
#  '天下',
#  '大吉',
#  '。',
#  '”',
#  '令人',
#  '各以',
#  '白土',
#  '書',
#  '“',
#  '甲子',
#  '”',
#  '二字',
#  '於',
#  '家中',
#  '\n',
#  '大門',
#  '上',
#  '。',
#  '青',
#  '、',
#  '幽',
#  '、',
#  '徐',
#  '、',
#  '冀',
#  '、',
#  '荊',
#  '、',
#  '揚',
#  '、',
#  '兗',
#  '、',
#  '豫八州',
#  '之',
#  '人',
#  '，',
#  '家家',
#  '侍',
#  '\n',
#  '奉大賢良師',
#  '張角',
#  '名字',
#  '。',
#  '角遣',
#  '其党馬元義',
#  '，',
#  '暗',
#  '齎',
#  '金帛',
#  '，',
#  '結交中',
#  '涓',
#  '\n',
#  '封諝',
#  '，',
#  '以',
#  '爲',
#  '內應',
#  '。',
#  '角',
#  '與',
#  '二角',
#  '商議',
#  '曰',
#  '：',
#  '“',
#  '至',
#  '難得者',
#  '，',
#  '民心',
#  '也',
#  '。',
#  '今',
#  '\n',
#  '民心',
#  '已順',
#  '，',
#  '若',
#  '不',
#  '乘勢',
#  '取',
#  '天下',
#  '，',
#  '誠',
#  '爲',
#  '可惜',
#  '。',
#  '”',
#  '遂',
#  '一面',
#  '私造',
#  '黃',
#  '旗',
#  '，',
#  '\n',
#  '約期',
#  '舉事',
#  '；',
#  '一面',
#  '使',
#  '弟子',
#  '唐周',
#  '，',
#  '馳書報',
#  '封諝',
#  '。',
#  '唐周',
#  '乃徑',
#  '赴',
#  '省',
#  '中告',
#  '\n',
#  '變',
#  '。',
#  '帝召大將',
#  '軍何',
#  '進調',
#  '兵',
#  '擒馬元義',
#  '，',
#  '斬',
#  '之',
#  '；',
#  '次收',
#  '封諝',
#  '等',
#  '一干人',
#  '\n',
#  '下獄',
#  '。',
#  '張角聞',
#  '知事',
#  '露',
#  '，',
#  '星夜',
#  '舉兵',
#  '，',
#  '自稱',
#  '“',
#  '天公',
#  '將軍',
#  '”',
#  '，',
#  '張寶稱',
#  '\n',
#  '“',
#  '地公將',
#  '軍',
#  '”',
#  '，',
#  '張梁',
#  '稱',
#  '“',
#  '人公將',
#  '軍',
#  '”',
#  '，',
#  '申言',
#  '於',
#  '衆',
#  '曰',
#  '：',
#  '“',
#  '今漢運',
#  '\n',
#  '將終',
#  '，',
#  '大聖人出',
#  '。',
#  '汝',
#  '等',
#  '皆宜',
#  '順天',
#  '從',
#  '正',
#  '，',
#  '以樂',
#  '太平',
#  '。',
#  '”',
#  '四方',
#  '百姓',
#  '，',
#  '\n',
#  '裹',
#  '黃',
#  '巾',
#  '從',
#  '張角',
#  '反者',
#  '四五十',
#  '萬',
#  '。',
#  '賊勢',
#  '浩大',
#  '，',
#  '官軍望',
#  '風而靡',
#  '。',
#  '何進',
#  '\n',
#  '奏帝',
#  '火速',
#  '降詔',
#  '，',
#  '令',
#  '各',
#  '處備',
#  '禦',
#  '，',
#  '討賊',
#  '立功',
#  '；',
#  '一面',
#  '遣',
#  '中郎將',
#  '盧植',
#  '、',
#  '\n',
#  '皇甫嵩',
#  '、',
#  '朱雋',
#  '，',
#  '各引',
#  '精兵',
#  '，',
#  '分',
#  '三路',
#  '討之',
#  '。',
#  '\n',
#  '且',
#  '說',
#  '張角',
#  '一',
#  '軍',
#  '，',
#  '前犯',
#  '幽州',
#  '界分',
#  '。',
#  '幽州',
#  '太守',
#  '劉焉',
#  '，',
#  '乃',
#  '江夏',
#  '竟',
#  '\n',
#  '陵',
#  '人氏',
#  '，',
#  '漢魯恭王',
#  '之',
#  '後',
#  '也',
#  '。',
#  '當時聞',
#  '得',
#  '賊',
#  '兵將',
#  '至',
#  '，',
#  '召',
#  '校尉',
#  '鄒靖計',
#  '\n',
#  ' ',
#  ' ',
#  '\n',
#  '議',
#  '。',
#  '靖',
#  '曰',
#  '：',
#  '“',
#  '賊',
#  '兵',
#  '衆',
#  '，',
#  '我兵',
#  '寡',
#  '，',
#  '明公宜',
#  '作速',
#  '招軍應',
#  '敵',
#  '。',
#  '”',
#  '劉焉',
#  '\n',
#  '然其',
#  '說',
#  '，',
#  '隨即',
#  '出榜',
#  '招募',
#  '義兵',
#  '。',
#  '\n',
#  '榜文',
#  '行到',
#  '涿縣',
#  '，',
#  '引出',
#  '涿縣',
#  '中',
#  '一個',
#  '英雄',
#  '。',
#  '那人',
#  '不',
#  '甚好',
#  '讀書',
#  '，',
#  '\n',
#  '性',
#  '寬',
#  '和',
#  '，',
#  '寡言',
#  '語',
#  '，',
#  '喜怒不形',
#  '於',
#  '色',
#  '。',
#  '素有',
#  '大志',
#  '，',
#  '專好',
#  '結交',
#  '天下',
#  '豪',
#  '\n',
#  '傑',
#  '。',
#  '生得',
#  '身長',
#  '七尺',
#  '五寸',
#  '，',
#  '兩',
#  '耳垂',
#  '肩',
#  '，',
#  '雙手',
#  '過膝',
#  '，',
#  '目能',
#  '自顧',
#  '其耳',
#  '，',
#  '\n',
#  '面如冠玉',
#  '，',
#  '唇',
#  '若',
#  '塗脂',
#  '。',
#  '—',
#  '—',
#  '中山',
#  '靖王',
#  '劉勝',
#  '之',
#  '後',
#  '，',
#  '漢景帝',
#  '閣',
#  '下',
#  '玄',
#  '\n',
#  '孫',
#  '—',
#  '—',
#  '姓劉',
#  '，',
#  '名備',
#  '，',
#  '字',
#  '玄德',
#  '。',
#  '昔',
#  '劉勝之子',
#  '劉貞',
#  '，',
#  '漢武時',
#  '封',
#  '涿鹿',
#  '\n',
#  '亭',
#  '侯',
#  '，',
#  '後',
#  '坐',
#  '酎',
#  '金失侯',
#  '，',
#  '因此',
#  '遺',
#  '這',
#  '一枝',
#  '在',
#  '涿縣',
#  '。',
#  '玄德祖',
#  '劉雄',
#  ...]

# %% [markdown]
# ### 字典

# %%
articleDict = {} # 这是一个字典，准备词-词频的保存

# %% [markdown]
# ### 集合（数据结构的一种）

# %%
articleSet = set(words)-dele

# %%
articleSet
# Out:
# {'卓大喜',
#  '其實',
#  '時常',
#  '舞刀',
#  '督郵作',
#  '捐宗廟',
#  '威風凜凜',
#  '數百人馬',
#  '數合',
#  '古錠',
#  '拜謝',
#  '進分',
#  '外合',
#  '漢家',
#  '星月',
#  '殺出',
#  '大怒',
#  '投關',
#  '舞',
#  '二謀士',
#  '兒願',
#  '麴',
#  '奮威將',
#  '傍邊',
#  '上山',
#  '折兵',
#  '飽餐',
#  '俄延',
#  '祖部領',
#  '堅',
#  '以明',
#  '誰何',
#  '齊出',
#  '神色',
#  '羽翼',
#  '肅豈敢',
#  '自應',
#  '餘黨',
#  '止',
#  '甯',
#  '命官',
#  '德',
#  '高壘',
#  '大鴻',
#  '其耳',
#  '孟德獻刀',
#  '之如',
#  '求赦',
#  '但',
#  '兩箭',
#  '鮑信',
#  '出戰',
#  '二千',
#  '卓已',
#  '亦',
#  '與',
#  '晨',
#  '其歌',
#  '亂',
#  '三匹',
#  '溫德殿',
#  '耽以頭',
#  '之力',
#  '眉黛',
#  '樓上',
#  '候賊',
#  '二賊',
#  '崔烈',
#  '竊視',
#  '跋扈',
#  '飛大',
#  '箭',
#  '正欲',
#  '張引數',
#  '血濺',
#  '缺少',
#  '三日',
#  '永昌',
#  '肥軀',
#  '韓忠果',
#  '遂吟詩',
#  '翔',
#  '陝人',
#  '遇一',
#  '圍如鐵桶',
#  '王室',
#  '精銳',
#  '文',
#  '正遇',
#  '舉樞',
#  '文官',
#  '審鈞意',
#  '武中興',
#  '侍張',
#  '不以',
#  '萬死',
#  '陶謙殺',
#  '泄漏',
#  '陷邕',
#  '追敵孫',
#  '忽有',
#  '門吏',
#  '忖',
#  '漫天',
#  '擡',
#  '除別',
#  '以達',
#  '邊讓',
#  '名宮',
#  '樊四人',
#  '欲謀',
#  '殞命',
#  '大船',
#  '宮樣',
#  '屍首',
#  '因挽布手',
#  '雞化',
#  '隨螢',
#  '嬰',
#  '諸將',
#  '登舟',
#  '高升',
#  '喚李',
#  '超一槍',
#  '良禽擇',
#  '背',
#  '擢用',
#  '始初',
#  '執筆',
#  '等然',
#  '閹官',
#  '鎮西將',
#  '何自',
#  '言于',
#  '盡令',
#  '一旦',
#  '溫厚純',
#  '看馬',
#  '高下',
#  '得利',
#  '二客',
#  '各通',
#  '私情',
#  '遂曰',
#  '帳下頭',
#  '絕大惡',
#  '封',
#  '之志則',
#  '甚見',
#  '玄德與關',
#  '一女',
#  '禦林',
#  '縣前',
#  '操大軍所到',
#  '宗派',
#  '紹方應',
#  '結交中',
#  '殘軍士',
#  '二十八年',
#  '乾象',
#  '少得',
#  '歸長',
#  '掩',
#  '目能',
#  '粉骨碎',
#  '接入',
#  '過去',
#  '瘦',
#  '卓大怒',
#  '快',
#  '宣卓入',
#  '殺',
#  '之車',
#  '嚴綱兵',
#  '高皇',
#  '李儒',
#  '出入',
#  '斟酒',
#  '牧丹亭',
#  '昌邑王',
#  '劫',
#  '天理',
#  '即將',
#  '扶起',
#  '入莊',
#  '程而去',
#  '三国演义',
#  '懸頭',
#  '悲慘',
#  '忘義',
#  '百里',
#  '虐者',
#  '爲',
#  '分兩路',
#  '昭陽宮',
#  '備言',
#  '館',
#  '不行',
#  '弓弩手',
#  '四路',
#  '平要術',
#  '澗',
#  '紹請入',
#  '高',
#  '還宮',
#  '劉勝之子',
#  '著孫策',
#  '斟下',
#  '邪',
#  '遭擒獲',
#  '左臂',
#  '黨',
#  '縱橫',
#  '記心',
#  '朝服',
#  '舌',
#  '砍死',
#  '擒馬元義',
#  '入朝議',
#  '彩帛',
#  '乘馬',
#  '風雷',
#  '配將',
#  '者',
#  '負心',
#  '延',
#  '聞',
#  '窺視良',
#  '怒目',
#  '汝父',
#  '飛至',
#  '臧',
#  '息',
#  '惟玄德',
#  '連軫還',
#  '山上',
#  '手足',
#  '竟來',
#  '恐此',
#  '不殺',
#  '想必',
#  '引著',
#  '三人衝',
#  '物',
#  '五萬來',
#  '作樂',
#  '家',
#  '操行',
#  '張角聞',
#  '邊',
#  '奢非',
#  '!',
#  '肅軍亂',
#  '千匹',
#  '暗',
#  '將吏',
#  '飛馬徑',
#  '覓',
#  '宗明靈',
#  '路引兵',
#  '江東方',
#  '功',
#  '必是',
#  '敗軍報',
#  '侍共議',
#  '良',
#  '無疑',
#  '留東門',
#  '至此',
#  '嬰將',
#  '自縱',
#  '童',
#  '有計',
#  '安降',
#  '酒尚',
#  '當乘間',
#  '除根',
#  '空中',
#  '太師功',
#  '守',
#  '家銓',
#  '肅當先',
#  '故人',
#  '請賞',
#  '睜圓',
#  '勤',
#  '餘匹',
#  '允命',
#  '不樂',
#  '張角正',
#  '將縱橫',
#  '肅然',
#  '認得',
#  '社',
#  '可輕動',
#  '吾料',
#  '粉骨碎身',
#  '將軍試思',
#  '不是',
#  '儒',
#  '胡軫',
#  '中牟',
#  '以避',
#  '箸',
#  '追急',
#  '降',
#  '涕泗',
#  '之私',
#  '傍缺',
#  '王允將',
#  '軍資',
#  '莫大',
#  '並不幹臣',
#  '面向',
#  '掌兵',
#  '些',
#  '鑿',
#  '無不驚',
#  '既',
#  '氏',
#  '一紅',
#  '必立',
#  '縱',
#  '謝罪',
#  '世之能',
#  '數中',
#  '起自',
#  '況國家',
#  '大喜',
#  '倘彼心',
#  '將軍擊',
#  '性命',
#  '操因',
#  '議溫明',
#  '欺主弄權',
#  '見卓',
#  '卓耳邊',
#  '今特',
#  '寡聞',
#  '其馬',
#  '披衣',
#  '忽折',
#  '妝',
#  '口稱',
#  '以震三輔',
#  '更近',
#  '勝於養',
#  '別事',
#  '私謂',
#  '不義',
#  '若何',
#  '治世',
#  '中官統',
#  '逃出',
#  '止樂',
#  '操',
#  '種邵外',
#  '麾',
#  '贊之',
#  '駕西幸',
#  '允非',
#  '頭戴',
#  '遺書于',
#  '軍哩',
#  '無敵',
#  '子密詔',
#  '一枝',
#  '張鈞車',
#  '掃清王',
#  '列坐',
#  '若非',
#  '司徒王允',
#  '日久',
#  '落到',
#  '萬刃',
#  '何患',
#  '閔貢',
#  '遠大之計',
#  '中小',
#  '韓遂',
#  '引軍趕',
#  '大旗',
#  '張寶死',
#  '自來',
#  '明珠',
#  '結怨',
#  '台大',
#  '贊之時',
#  '公共',
#  '之中',
#  '李儒入',
#  '引玄德',
#  '登岸',
#  '命備',
#  '太常卿',
#  '乘夜',
#  '下榻',
#  '大會聞者',
#  '蟬立',
#  '相新棄',
#  '溫時',
#  '並皆殺',
#  '良民',
#  '地養',
#  '桓階',
#  '問東',
#  '中子',
#  '反而',
#  '驛庭',
#  '行權',
#  '公引',
#  '豐前',
#  '諸侯皆言',
#  '元年',
#  '兩行',
#  '子治',
#  '兵圍',
#  '溝壑者',
#  '望此',
#  '不足以',
#  '錯敬',
#  '采藥',
#  '貴人',
#  '直透',
#  '郎蔡邕',
#  '獲罪',
#  '鼓掌',
#  '其計',
#  '聽調',
#  '此名',
#  '不忍',
#  '乘此',
#  '渡河',
#  '作亂',
#  '逃',
#  '曹公破',
#  '濃眉大眼',
#  '甲子',
#  '垂偉績',
#  '此天助',
#  '欲煩',
#  '今見',
#  '歸鄉',
#  '奄有',
#  '太子',
#  '操切',
#  '細詳',
#  '因見紹',
#  '馳書',
#  '血',
#  '酌酒',
#  '奉宗廟',
#  '愛于',
#  '俱奔避',
#  '回鄉',
#  '韓遂勒馬',
#  '操入',
#  '盡皆誅絕',
#  '各自',
#  '操見',
#  '中鳳',
#  '下獄',
#  '刺數',
#  '舊日',
#  '故久',
#  '左有',
#  '前',
#  '來朝',
#  '國運',
#  '雕鞍',
#  '以黃巾',
#  '掌中',
#  '盔',
#  '祭罷',
#  '知而故',
#  '卓甚輕',
#  '出園門',
#  '不俗',
#  '諸鎮應',
#  '宮中來',
#  '誠非',
#  '宇',
#  '容納否',
#  '教省',
#  '謂',
#  '無罪',
#  '非公有',
#  '起身',
#  '一點',
#  '志告',
#  '推其致',
#  '投',
#  '放箭',
#  '乃督郵',
#  '張寶去',
#  '允視',
#  '寺',
#  '點軍司',
#  '牛輔喚',
#  '三戰虎',
#  '手',
#  '自引',
#  '勒兵',
#  '郵之罪',
#  '畔',
#  '何後過',
#  '呂公',
#  '激得',
#  '此冤',
#  '同請',
#  '乃典',
#  '軍之名',
#  '速入',
#  '尚父',
#  '鳳儀',
#  '布沈吟',
#  '名飛',
#  '除害',
#  '好處',
#  '履上',
#  '將謂',
#  '城池',
#  '王莽',
#  '身無見',
#  '此天',
#  '弘槊',
#  '前到',
#  '本當',
#  '未寧',
#  '鳴金',
#  '字伯符',
#  '妄殺',
#  '碩慌',
#  '陣後殺',
#  '使鐵鞭',
#  '披',
#  '屠戮',
#  '今將',
#  '張助',
#  '敬賢禮士',
#  '五十匹',
#  '曄',
#  '妻子',
#  '卓側',
#  '樂宮',
#  '三百',
#  '之胄',
#  '漢水',
#  '嘗師事',
#  '軍用',
#  '自行',
#  '萬世統',
#  '盡將家產',
#  '神功',
#  '轉馬頭',
#  '一能',
#  '特上',
#  '發書',
#  '其宗黨',
#  '州郡',
#  '免致',
#  '上止',
#  '引水',
#  '投操',
#  '功者賞',
#  '血戰',
#  '一人伏',
#  '驚',
#  '軍入',
#  '矣',
#  '周奐',
#  '回到',
#  '插劍',
#  '誅戮',
#  '三合',
#  '智勇',
#  '孫策釋',
#  '報',
#  '名韶',
#  '四子',
#  '赴宴',
#  '孟德有',
#  '八路',
#  '可教',
#  '八俊',
#  '今無故',
#  '其盟',
#  '束草',
#  '入于',
#  '之心',
#  '戰不數合',
#  '風雨',
#  '人實',
#  '汝當速',
#  '措手不及',
#  '願將',
#  '只因',
#  '好言相',
#  '仇隙',
#  '造惡',
#  '賄賂',
#  '趕至翠花樓',
#  '待',
#  '出關',
#  '禍',
#  '軍滎陽',
#  '袁',
#  '夏侯',
#  '連夜',
#  '入',
#  '井中',
#  '要行',
#  '字仲麟',
#  '督郵先',
#  '食祿漢朝',
#  '用兵',
#  '誘他',
#  '面如',
#  '北行',
#  '虎狼',
#  '喚貂蟬問',
#  '立馬于',
#  '汝本',
#  '義身',
#  '惱怒',
#  '汝',
#  '汝有何',
#  '暢飲',
#  '宜假',
#  '一首',
#  '捉黃祖',
#  '以前',
#  '郭二賊',
#  '抹額',
#  '只見',
#  '甚是',
#  '乃出',
#  '明仁',
#  '壁間',
#  '發冠',
#  '霍光',
#  '束手待死',
#  '陶',
#  '到關',
#  '戶逢',
#  '雄耳',
#  '腹之交',
#  '護從',
#  '徐州',
#  '到界橋',
#  '現任',
#  '憂喜',
#  '武士',
#  '人亂',
#  '植大呼',
#  '高岡望',
#  '窺',
#  '城',
#  '金失侯',
#  '一桃園',
#  '招募',
#  '察',
#  '窮',
#  '安能',
#  '騎馬',
#  '入長',
#  '自盡',
#  '檀',
#  '及桓帝',
#  '舟將',
#  '彧',
#  '十四',
#  '鬃',
#  '邕懼',
#  '然允',
#  '當送',
#  '尚敢',
#  '手起刀落',
#  '操拜',
#  '輸首級',
#  '回頭問',
#  '聚鄉',
#  '字世元',
#  '侍',
#  '人身',
#  '失色',
#  '將得',
#  '奏獻帝',
#  '抄小路',
#  '實不悟',
#  '主與',
#  '其路',
#  '燕雀安知',
#  '一封',
#  '始皇',
#  '雖',
#  '遂解',
#  '嘶喊',
#  '先來',
#  '寢則',
#  '從者',
#  '憂',
#  '隘口',
#  '時報',
#  '人否',
#  '赴任',
#  '出內門',
#  '半個',
#  '急欲退',
#  '夏侯惇',
#  '便令堅',
#  '儒適',
#  '連聲',
#  '楚',
#  '名堅',
#  '貢與',
#  '先皇',
#  '交紐',
#  '還能',
#  '西涼兵',
#  '漢末',
#  '泗',
#  '堅先',
#  '盛貯',
#  '布驚',
#  '玄德兵',
#  '司徒',
#  '玄德甚',
#  '久慕',
#  '同族',
#  '好遊獵',
#  '逆',
#  '顧',
#  '不密',
#  '見紹',
#  '反受',
#  '玉璽',
#  '雪恨',
#  '祖引',
#  '西頭',
#  '當有',
#  '一陣',
#  '應弦落',
#  '累及',
#  '無馬匹',
#  '嵩自陳留',
#  '行至',
#  '張角',
#  '一連',
#  '足踐',
#  '麾下',
#  '區星',
#  '屈身',
#  '聽候',
#  '闊面',
#  '故令',
#  '于長',
#  '數百萬',
#  '二尺',
#  '坐定',
#  '此丁',
#  '賣酒',
#  '如翼德',
#  '廝',
#  '喜',
#  '大隊',
#  '就橋',
#  '瞞',
#  '汝何',
#  '獲得',
#  '紹入',
#  '道',
#  '計較',
#  '蠻寶帶',
#  '自初',
#  '二角',
#  '紹聚',
#  '一彪',
#  '多帶',
#  '鴻鵠志',
#  '所言',
#  '朝延微',
#  '赴',
#  '以誤',
#  '以',
#  '偷開城',
#  '椅上',
#  '伎',
#  '微笑',
#  '欠身',
#  '八百弓',
#  '表曰',
#  '令良',
#  '或斷',
#  '侯長',
#  '虎賁',
#  '關上',
#  '走北',
#  '一路',
#  '路而來',
#  '得安國家',
#  '重',
#  '洛陽小兒',
#  '侍賣官',
#  '人',
#  '久住',
#  '保用',
#  '操父',
#  '義氣',
#  '蒯',
#  '新君',
#  '當世一人',
#  '鋼矛',
#  '言則',
#  '駭',
#  '大刀',
#  '乃尚書',
#  '申言',
#  '孟德',
#  '劉表許',
#  '帝然',
#  '應募',
#  '著',
#  '領州事',
#  '三子',
#  '孟德何',
#  '之謀',
#  '相撞',
#  '聖德偉懋',
#  '東',
#  '拱手',
#  '執寶劍',
#  '善言',
#  '驛',
#  '重任',
#  '叩頭',
#  '自是',
#  '’',
#  '毋乃有',
#  '默然',
#  '至府門',
#  '司',
#  '角得',
#  '前廳',
#  '肅遂',
#  '文醜',
#  '應聲',
#  '立太子',
#  '綬',
#  '象簡',
#  '一群',
#  '故霍光',
#  '祀',
#  '探知',
#  '娘垂憐',
#  '不成',
#  '那何',
#  '仗忠義',
#  '不止',
#  '庭中',
#  '此四人',
#  '策許',
#  '飛迎',
#  '堅又過',
#  '功名',
#  '率南陽',
#  '高祖',
#  '封列侯',
#  '二面',
#  '重頤',
#  '謠',
#  '潁川',
#  '恢見',
#  '偶有家',
#  '樊稠四人',
#  '妻小',
#  '已喪',
#  '爾',
#  '引軍迎',
#  '出射獵',
#  '若令',
#  '寬懷',
#  '便行',
#  '忽轉',
#  '速致',
#  '眼望',
#  '托紅裙',
#  '如不勝',
#  '策文',
#  '劉焉',
#  '崩裂',
#  '心虛',
#  '今悉',
#  '即日',
#  '園門外',
#  '卓引操',
#  '擅入',
#  '紹喚',
#  '雲衝',
#  '軍耳',
#  '相',
#  '奔走',
#  '名進',
#  '路逢',
#  '州',
#  '有何不可',
#  '據汝害民',
#  '其叔',
#  '進本',
#  '至北',
#  '負我',
#  '偶見',
#  '白',
#  '截',
#  '今居何',
#  '靈',
#  '連珠',
#  '操解悶',
#  '蟬亦不見',
#  '操徑',
#  '今已',
#  '俯伏',
#  '大名',
#  '敖倉',
#  '夜行',
#  '奉命',
#  '允指',
#  '主',
#  '已據',
#  '侍立',
#  '迎養',
#  '實',
#  '成漢史',
#  '引馬步',
#  '腰',
#  '計議',
#  '應',
#  '表薦',
#  '雲連',
#  '近侍',
#  '其如',
#  '果得',
#  '之一',
#  '突至',
#  '王允得',
#  '救滅',
#  '往京師',
#  '衣襟',
#  '既雲壽酒',
#  '布大怒',
#  '羌人',
#  '劉范',
#  '曩',
#  '機事',
#  '鎖著',
#  '植亦諫',
#  '備願',
#  '簾外',
#  '施小策',
#  '蔽天',
#  '亭',
#  '兩傍',
#  '密詔付',
#  '夾攻',
#  '第六回',
#  '玄德幼',
#  '玄',
#  '隨丁建陽',
#  '以致',
#  '虛實',
#  '某遍觀',
#  '獸面',
#  '其原',
#  '兇暴',
#  '往視',
#  '絲',
#  '布便',
#  '釋放',
#  '喝退',
#  '投一',
#  '堅臨行',
#  '那七人',
#  '挺',
#  '時分',
#  '河邊',
#  '可請汝兄',
#  '侍中',
#  '股掌之上',
#  '傾',
#  '千丈',
#  '玄德家',
#  '皆側',
#  '驅使',
#  '之民數',
#  '微垣',
#  '命',
#  '想漢',
#  '當解',
#  '倘若',
#  '殺伐',
#  ...}

# %%
# 因为采用的是循环的方法，把所有的词都循环一遍，长度大于1，所以速度很慢！

# %%
for w in articleSet:
    if len(w)>1:
        articleDict[w] = words.count(w)  # 字典的key-value配对

# %%
articleDict
# Out:
# {'卓大喜': 5,
#  '其實': 1,
#  '時常': 1,
#  '舞刀': 2,
#  '督郵作': 1,
#  '捐宗廟': 1,
#  '威風凜凜': 2,
#  '數百人馬': 1,
#  '數合': 5,
#  '古錠': 1,
#  '拜謝': 3,
#  '進分': 1,
#  '外合': 1,
#  '漢家': 2,
#  '星月': 1,
#  '殺出': 1,
#  '大怒': 5,
#  '投關': 1,
#  '二謀士': 1,
#  '兒願': 1,
#  '奮威將': 1,
#  '傍邊': 2,
#  '上山': 3,
#  '折兵': 1,
#  '飽餐': 1,
#  '俄延': 2,
#  '祖部領': 1,
#  '以明': 1,
#  '誰何': 1,
#  '齊出': 3,
#  '神色': 1,
#  '羽翼': 2,
#  '肅豈敢': 1,
#  '自應': 2,
#  '餘黨': 3,
#  '命官': 1,
#  '高壘': 5,
#  '大鴻': 1,
#  '其耳': 1,
#  '孟德獻刀': 1,
#  '之如': 1,
#  '求赦': 2,
#  '兩箭': 1,
#  '鮑信': 9,
#  '出戰': 5,
#  '二千': 1,
#  '卓已': 1,
#  '其歌': 1,
#  '三匹': 1,
#  '溫德殿': 2,
#  '耽以頭': 1,
#  '之力': 1,
#  '眉黛': 1,
#  '樓上': 1,
#  '候賊': 1,
#  '二賊': 2,
#  '崔烈': 2,
#  '竊視': 1,
#  '跋扈': 2,
#  '飛大': 1,
#  '正欲': 1,
#  '張引數': 1,
#  '血濺': 1,
#  '缺少': 2,
#  '三日': 2,
#  '永昌': 1,
#  '肥軀': 1,
#  '韓忠果': 1,
#  '遂吟詩': 1,
#  '陝人': 1,
#  '遇一': 1,
#  '圍如鐵桶': 1,
#  '王室': 4,
#  '精銳': 1,
#  '正遇': 4,
#  '舉樞': 1,
#  '文官': 1,
#  '審鈞意': 1,
#  '武中興': 1,
#  '侍張': 1,
#  '不以': 1,
#  '萬死': 4,
#  '陶謙殺': 1,
#  '泄漏': 3,
#  '陷邕': 1,
#  '追敵孫': 1,
#  '忽有': 1,
#  '門吏': 1,
#  '漫天': 1,
#  '除別': 1,
#  '以達': 1,
#  '邊讓': 1,
#  '名宮': 1,
#  '樊四人': 1,
#  '欲謀': 2,
#  '殞命': 1,
#  '大船': 1,
#  '宮樣': 1,
#  '屍首': 7,
#  '因挽布手': 1,
#  '雞化': 1,
#  '隨螢': 1,
#  '諸將': 1,
#  '登舟': 1,
#  '高升': 1,
#  '喚李': 1,
#  '超一槍': 1,
#  '良禽擇': 1,
#  '擢用': 1,
#  '始初': 2,
#  '執筆': 1,
#  '等然': 1,
#  '閹官': 3,
#  '鎮西將': 1,
#  '何自': 1,
#  '言于': 2,
#  '盡令': 1,
#  '一旦': 1,
#  '溫厚純': 1,
#  '看馬': 1,
#  '高下': 1,
#  '得利': 1,
#  '二客': 2,
#  '各通': 1,
#  '私情': 1,
#  '遂曰': 1,
#  '帳下頭': 1,
#  '絕大惡': 1,
#  '之志則': 1,
#  '甚見': 1,
#  '玄德與關': 2,
#  '一女': 1,
#  '禦林': 1,
#  '縣前': 2,
#  '操大軍所到': 1,
#  '宗派': 2,
#  '紹方應': 1,
#  '結交中': 1,
#  '殘軍士': 2,
#  '二十八年': 1,
#  '乾象': 1,
#  '少得': 1,
#  '歸長': 1,
#  '目能': 1,
#  '粉骨碎': 1,
#  '接入': 2,
#  '過去': 3,
#  '卓大怒': 6,
#  '宣卓入': 1,
#  '之車': 1,
#  '嚴綱兵': 1,
#  '高皇': 1,
#  '李儒': 25,
#  '出入': 3,
#  '斟酒': 1,
#  '牧丹亭': 1,
#  '昌邑王': 1,
#  '天理': 1,
#  '即將': 1,
#  '扶起': 1,
#  '入莊': 1,
#  '程而去': 1,
#  '三国演义': 1,
#  '懸頭': 3,
#  '悲慘': 1,
#  '忘義': 1,
#  '百里': 1,
#  '虐者': 1,
#  '分兩路': 1,
#  '昭陽宮': 1,
#  '備言': 1,
#  '不行': 1,
#  '弓弩手': 3,
#  '四路': 2,
#  '平要術': 1,
#  '紹請入': 1,
#  '還宮': 1,
#  '劉勝之子': 1,
#  '著孫策': 1,
#  '斟下': 1,
#  '遭擒獲': 1,
#  '左臂': 1,
#  '縱橫': 1,
#  '記心': 1,
#  '朝服': 2,
#  '砍死': 2,
#  '擒馬元義': 1,
#  '入朝議': 1,
#  '彩帛': 1,
#  '乘馬': 5,
#  '風雷': 2,
#  '配將': 1,
#  '負心': 2,
#  '窺視良': 1,
#  '怒目': 1,
#  '汝父': 1,
#  '飛至': 1,
#  '惟玄德': 1,
#  '連軫還': 1,
#  '山上': 2,
#  '手足': 1,
#  '竟來': 1,
#  '恐此': 1,
#  '不殺': 1,
#  '想必': 1,
#  '引著': 1,
#  '三人衝': 2,
#  '五萬來': 1,
#  '作樂': 1,
#  '操行': 1,
#  '張角聞': 1,
#  '奢非': 1,
#  '肅軍亂': 1,
#  '千匹': 1,
#  '將吏': 1,
#  '飛馬徑': 1,
#  '宗明靈': 1,
#  '路引兵': 1,
#  '江東方': 1,
#  '必是': 1,
#  '敗軍報': 1,
#  '侍共議': 1,
#  '無疑': 1,
#  '留東門': 1,
#  '至此': 4,
#  '嬰將': 1,
#  '自縱': 1,
#  '有計': 1,
#  '安降': 1,
#  '酒尚': 1,
#  '當乘間': 1,
#  '除根': 1,
#  '空中': 1,
#  '太師功': 1,
#  '家銓': 1,
#  '肅當先': 1,
#  '故人': 2,
#  '請賞': 2,
#  '睜圓': 1,
#  '餘匹': 1,
#  '允命': 2,
#  '不樂': 2,
#  '張角正': 2,
#  '將縱橫': 1,
#  '肅然': 1,
#  '認得': 2,
#  '可輕動': 2,
#  '吾料': 1,
#  '粉骨碎身': 1,
#  '將軍試思': 1,
#  '不是': 2,
#  '胡軫': 4,
#  '中牟': 1,
#  '以避': 1,
#  '追急': 1,
#  '涕泗': 1,
#  '之私': 1,
#  '傍缺': 1,
#  '王允將': 1,
#  '軍資': 1,
#  '莫大': 1,
#  '並不幹臣': 1,
#  '面向': 1,
#  '掌兵': 1,
#  '無不驚': 1,
#  '一紅': 1,
#  '必立': 1,
#  '謝罪': 1,
#  '世之能': 1,
#  '數中': 1,
#  '起自': 1,
#  '況國家': 1,
#  '大喜': 21,
#  '倘彼心': 1,
#  '將軍擊': 1,
#  '性命': 12,
#  '操因': 1,
#  '議溫明': 1,
#  '欺主弄權': 1,
#  '見卓': 2,
#  '卓耳邊': 1,
#  '今特': 1,
#  '寡聞': 1,
#  '其馬': 1,
#  '披衣': 1,
#  '忽折': 1,
#  '口稱': 2,
#  '以震三輔': 1,
#  '更近': 1,
#  '勝於養': 1,
#  '別事': 1,
#  '私謂': 2,
#  '不義': 1,
#  '若何': 7,
#  '治世': 1,
#  '中官統': 1,
#  '逃出': 1,
#  '止樂': 1,
#  '種邵外': 1,
#  '贊之': 1,
#  '駕西幸': 1,
#  '允非': 1,
#  '頭戴': 1,
#  '遺書于': 1,
#  '軍哩': 1,
#  '無敵': 1,
#  '子密詔': 1,
#  '一枝': 4,
#  '張鈞車': 1,
#  '掃清王': 1,
#  '列坐': 1,
#  '若非': 3,
#  '司徒王允': 4,
#  '日久': 2,
#  '落到': 1,
#  '萬刃': 1,
#  '何患': 1,
#  '閔貢': 2,
#  '遠大之計': 1,
#  '中小': 1,
#  '韓遂': 9,
#  '引軍趕': 1,
#  '大旗': 1,
#  '張寶死': 2,
#  '自來': 2,
#  '明珠': 1,
#  '結怨': 1,
#  '台大': 1,
#  '贊之時': 1,
#  '公共': 1,
#  '之中': 2,
#  '李儒入': 1,
#  '引玄德': 1,
#  '登岸': 1,
#  '命備': 1,
#  '太常卿': 1,
#  '乘夜': 1,
#  '下榻': 1,
#  '大會聞者': 1,
#  '蟬立': 1,
#  '相新棄': 1,
#  '溫時': 1,
#  '並皆殺': 1,
#  '良民': 1,
#  '地養': 1,
#  '桓階': 2,
#  '問東': 1,
#  '中子': 1,
#  '反而': 1,
#  '驛庭': 1,
#  '行權': 1,
#  '公引': 2,
#  '豐前': 2,
#  '諸侯皆言': 1,
#  '元年': 2,
#  '兩行': 4,
#  '子治': 1,
#  '兵圍': 1,
#  '溝壑者': 1,
#  '望此': 1,
#  '不足以': 1,
#  '錯敬': 1,
#  '采藥': 1,
#  '貴人': 3,
#  '直透': 1,
#  '郎蔡邕': 1,
#  '獲罪': 1,
#  '鼓掌': 1,
#  '其計': 3,
#  '聽調': 2,
#  '此名': 1,
#  '不忍': 4,
#  '乘此': 2,
#  '渡河': 1,
#  '作亂': 3,
#  '曹公破': 1,
#  '濃眉大眼': 1,
#  '甲子': 2,
#  '垂偉績': 2,
#  '此天助': 1,
#  '欲煩': 1,
#  '今見': 1,
#  '歸鄉': 2,
#  '奄有': 1,
#  '太子': 2,
#  '操切': 1,
#  '細詳': 1,
#  '因見紹': 1,
#  '馳書': 1,
#  '酌酒': 2,
#  '奉宗廟': 1,
#  '愛于': 2,
#  '俱奔避': 1,
#  '回鄉': 2,
#  '韓遂勒馬': 1,
#  '操入': 1,
#  '盡皆誅絕': 1,
#  '各自': 8,
#  '操見': 3,
#  '中鳳': 1,
#  '下獄': 3,
#  '刺數': 1,
#  '舊日': 2,
#  '故久': 1,
#  '左有': 1,
#  '來朝': 1,
#  '國運': 1,
#  '雕鞍': 1,
#  '以黃巾': 1,
#  '掌中': 1,
#  '祭罷': 1,
#  '知而故': 1,
#  '卓甚輕': 2,
#  '出園門': 1,
#  '不俗': 1,
#  '諸鎮應': 1,
#  '宮中來': 1,
#  '誠非': 1,
#  '容納否': 1,
#  '教省': 1,
#  '無罪': 1,
#  '非公有': 1,
#  '起身': 4,
#  '一點': 1,
#  '志告': 1,
#  '推其致': 1,
#  '放箭': 3,
#  '乃督郵': 1,
#  '張寶去': 2,
#  '允視': 1,
#  '點軍司': 1,
#  '牛輔喚': 1,
#  '三戰虎': 1,
#  '自引': 2,
#  '勒兵': 2,
#  '郵之罪': 1,
#  '何後過': 1,
#  '呂公': 4,
#  '激得': 1,
#  '此冤': 1,
#  '同請': 1,
#  '乃典': 1,
#  '軍之名': 1,
#  '速入': 1,
#  '尚父': 1,
#  '鳳儀': 1,
#  '布沈吟': 1,
#  '名飛': 1,
#  '除害': 2,
#  '好處': 1,
#  '履上': 1,
#  '將謂': 1,
#  '城池': 2,
#  '王莽': 1,
#  '身無見': 1,
#  '此天': 2,
#  '弘槊': 1,
#  '前到': 1,
#  '本當': 1,
#  '未寧': 1,
#  '鳴金': 4,
#  '字伯符': 1,
#  '妄殺': 1,
#  '碩慌': 1,
#  '陣後殺': 1,
#  '使鐵鞭': 1,
#  '屠戮': 1,
#  '今將': 2,
#  '張助': 1,
#  '敬賢禮士': 1,
#  '五十匹': 1,
#  '妻子': 1,
#  '卓側': 1,
#  '樂宮': 2,
#  '三百': 1,
#  '之胄': 1,
#  '漢水': 2,
#  '嘗師事': 1,
#  '軍用': 1,
#  '自行': 1,
#  '萬世統': 1,
#  '盡將家產': 1,
#  '神功': 2,
#  '轉馬頭': 1,
#  '一能': 1,
#  '特上': 1,
#  '發書': 1,
#  '其宗黨': 1,
#  '州郡': 2,
#  '免致': 1,
#  '上止': 1,
#  '引水': 1,
#  '投操': 2,
#  '功者賞': 1,
#  '血戰': 2,
#  '一人伏': 1,
#  '軍入': 2,
#  '周奐': 1,
#  '回到': 1,
#  '插劍': 1,
#  '誅戮': 1,
#  '三合': 1,
#  '智勇': 1,
#  '孫策釋': 1,
#  '名韶': 1,
#  '四子': 2,
#  '赴宴': 2,
#  '孟德有': 2,
#  '八路': 3,
#  '可教': 1,
#  '八俊': 1,
#  '今無故': 1,
#  '其盟': 1,
#  '束草': 1,
#  '入于': 1,
#  '之心': 2,
#  '戰不數合': 2,
#  '風雨': 1,
#  '人實': 1,
#  '汝當速': 1,
#  '措手不及': 2,
#  '願將': 1,
#  '只因': 1,
#  '好言相': 1,
#  '仇隙': 1,
#  '造惡': 1,
#  '賄賂': 4,
#  '趕至翠花樓': 1,
#  '出關': 2,
#  '軍滎陽': 1,
#  '夏侯': 7,
#  '連夜': 4,
#  '井中': 2,
#  '要行': 1,
#  '字仲麟': 1,
#  '督郵先': 1,
#  '食祿漢朝': 1,
#  '用兵': 1,
#  '誘他': 1,
#  '面如': 2,
#  '北行': 1,
#  '虎狼': 1,
#  '喚貂蟬問': 1,
#  '立馬于': 1,
#  '汝本': 1,
#  '義身': 1,
#  '惱怒': 1,
#  '汝有何': 1,
#  '暢飲': 2,
#  '宜假': 1,
#  '一首': 1,
#  '捉黃祖': 1,
#  '以前': 2,
#  '郭二賊': 1,
#  '抹額': 1,
#  '只見': 14,
#  '甚是': 1,
#  '乃出': 2,
#  '明仁': 1,
#  '壁間': 1,
#  '發冠': 1,
#  '霍光': 1,
#  '束手待死': 1,
#  '到關': 1,
#  '戶逢': 1,
#  '雄耳': 1,
#  '腹之交': 1,
#  '護從': 1,
#  '徐州': 9,
#  '到界橋': 1,
#  '現任': 1,
#  '憂喜': 1,
#  '武士': 9,
#  '人亂': 1,
#  '植大呼': 1,
#  '高岡望': 2,
#  '金失侯': 1,
#  '一桃園': 1,
#  '招募': 4,
#  '安能': 1,
#  '騎馬': 2,
#  '入長': 1,
#  '自盡': 1,
#  '及桓帝': 1,
#  '舟將': 1,
#  '十四': 1,
#  '邕懼': 1,
#  '然允': 1,
#  '當送': 1,
#  '尚敢': 1,
#  '手起刀落': 1,
#  '操拜': 1,
#  '輸首級': 1,
#  '回頭問': 1,
#  '聚鄉': 1,
#  '字世元': 1,
#  '人身': 2,
#  '失色': 4,
#  '將得': 1,
#  '奏獻帝': 1,
#  '抄小路': 1,
#  '實不悟': 1,
#  '主與': 1,
#  '其路': 1,
#  '燕雀安知': 1,
#  '一封': 1,
#  '始皇': 3,
#  '遂解': 2,
#  '嘶喊': 2,
#  '先來': 1,
#  '寢則': 1,
#  '從者': 6,
#  '隘口': 1,
#  '時報': 1,
#  '人否': 1,
#  '赴任': 2,
#  '出內門': 1,
#  '半個': 1,
#  '急欲退': 1,
#  '夏侯惇': 9,
#  '便令堅': 1,
#  '儒適': 1,
#  '連聲': 1,
#  '名堅': 1,
#  '貢與': 1,
#  '先皇': 1,
#  '交紐': 1,
#  '還能': 1,
#  '西涼兵': 2,
#  '漢末': 1,
#  '堅先': 1,
#  '盛貯': 1,
#  '布驚': 1,
#  '玄德兵': 1,
#  '司徒': 18,
#  '玄德甚': 2,
#  '久慕': 1,
#  '同族': 1,
#  '好遊獵': 2,
#  '不密': 3,
#  '見紹': 1,
#  '反受': 1,
#  '玉璽': 3,
#  '雪恨': 1,
#  '祖引': 1,
#  '西頭': 2,
#  '當有': 1,
#  '一陣': 4,
#  '應弦落': 1,
#  '累及': 1,
#  '無馬匹': 1,
#  '嵩自陳留': 1,
#  '行至': 2,
#  '張角': 15,
#  '一連': 4,
#  '足踐': 1,
#  '麾下': 3,
#  '區星': 1,
#  '屈身': 3,
#  '聽候': 1,
#  '闊面': 2,
#  '故令': 1,
#  '于長': 1,
#  '數百萬': 1,
#  '二尺': 2,
#  '坐定': 2,
#  '此丁': 1,
#  '賣酒': 1,
#  '如翼德': 2,
#  '大隊': 1,
#  '就橋': 1,
#  '汝何': 3,
#  '獲得': 2,
#  '紹入': 1,
#  '計較': 1,
#  '蠻寶帶': 1,
#  '自初': 1,
#  '二角': 1,
#  '紹聚': 1,
#  '一彪': 7,
#  '多帶': 1,
#  '鴻鵠志': 1,
#  '所言': 1,
#  '朝延微': 1,
#  '以誤': 1,
#  '偷開城': 1,
#  '椅上': 1,
#  '微笑': 1,
#  '欠身': 2,
#  '八百弓': 2,
#  '表曰': 4,
#  '令良': 1,
#  '或斷': 1,
#  '侯長': 1,
#  '虎賁': 2,
#  '關上': 4,
#  '走北': 1,
#  '一路': 3,
#  '路而來': 1,
#  '得安國家': 1,
#  '洛陽小兒': 1,
#  '侍賣官': 1,
#  '久住': 1,
#  '保用': 1,
#  '操父': 3,
#  '義氣': 1,
#  '新君': 1,
#  '當世一人': 1,
#  '鋼矛': 1,
#  '言則': 1,
#  '大刀': 2,
#  '乃尚書': 1,
#  '申言': 1,
#  '孟德': 4,
#  '劉表許': 1,
#  '帝然': 1,
#  '應募': 2,
#  '領州事': 1,
#  '三子': 1,
#  '孟德何': 1,
#  '之謀': 2,
#  '相撞': 1,
#  '聖德偉懋': 1,
#  '拱手': 1,
#  '執寶劍': 1,
#  '善言': 1,
#  '重任': 1,
#  '叩頭': 1,
#  '自是': 1,
#  '毋乃有': 1,
#  '默然': 1,
#  '至府門': 1,
#  '角得': 1,
#  '前廳': 1,
#  '肅遂': 1,
#  '文醜': 15,
#  '應聲': 3,
#  '立太子': 1,
#  '象簡': 1,
#  '一群': 1,
#  '故霍光': 1,
#  '探知': 1,
#  '娘垂憐': 1,
#  '不成': 4,
#  '那何': 1,
#  '仗忠義': 1,
#  '不止': 2,
#  '庭中': 1,
#  '此四人': 1,
#  '策許': 1,
#  '飛迎': 1,
#  '堅又過': 1,
#  '功名': 1,
#  '率南陽': 1,
#  '高祖': 3,
#  '封列侯': 3,
#  '二面': 2,
#  '重頤': 1,
#  '潁川': 7,
#  '恢見': 1,
#  '偶有家': 1,
#  '樊稠四人': 1,
#  '妻小': 1,
#  '已喪': 1,
#  '引軍迎': 1,
#  '出射獵': 1,
#  '若令': 1,
#  '寬懷': 1,
#  '便行': 2,
#  '忽轉': 1,
#  '速致': 1,
#  '眼望': 2,
#  '托紅裙': 1,
#  '如不勝': 1,
#  '策文': 1,
#  '劉焉': 7,
#  '崩裂': 1,
#  '心虛': 1,
#  '今悉': 1,
#  '即日': 7,
#  '園門外': 1,
#  '卓引操': 1,
#  '擅入': 1,
#  '紹喚': 1,
#  '雲衝': 1,
#  '軍耳': 1,
#  '奔走': 8,
#  '名進': 1,
#  '路逢': 1,
#  '有何不可': 1,
#  '據汝害民': 1,
#  '其叔': 1,
#  '進本': 1,
#  '至北': 1,
#  '負我': 1,
#  '偶見': 1,
#  '今居何': 2,
#  '連珠': 1,
#  '操解悶': 1,
#  '蟬亦不見': 1,
#  '操徑': 1,
#  '今已': 2,
#  '俯伏': 1,
#  '大名': 1,
#  '敖倉': 1,
#  '夜行': 2,
#  '奉命': 1,
#  '允指': 1,
#  '已據': 1,
#  '侍立': 5,
#  '迎養': 1,
#  '成漢史': 2,
#  '引馬步': 2,
#  '計議': 2,
#  '表薦': 1,
#  '雲連': 1,
#  '近侍': 1,
#  '其如': 1,
#  '果得': 1,
#  '之一': 2,
#  '突至': 1,
#  '王允得': 1,
#  '救滅': 3,
#  '往京師': 1,
#  '衣襟': 1,
#  '既雲壽酒': 1,
#  '布大怒': 1,
#  '羌人': 1,
#  '劉范': 1,
#  '機事': 1,
#  '鎖著': 1,
#  '植亦諫': 1,
#  '備願': 1,
#  '簾外': 1,
#  '施小策': 1,
#  '蔽天': 1,
#  '兩傍': 1,
#  '密詔付': 1,
#  '夾攻': 4,
#  '第六回': 1,
#  '玄德幼': 1,
#  '隨丁建陽': 1,
#  '以致': 6,
#  '虛實': 1,
#  '某遍觀': 1,
#  '獸面': 1,
#  '其原': 1,
#  '兇暴': 1,
#  '往視': 1,
#  '布便': 1,
#  '釋放': 1,
#  '喝退': 1,
#  '投一': 1,
#  '堅臨行': 1,
#  '那七人': 1,
#  '時分': 1,
#  '河邊': 1,
#  '可請汝兄': 1,
#  '侍中': 7,
#  '股掌之上': 1,
#  '千丈': 1,
#  '玄德家': 1,
#  '皆側': 1,
#  '驅使': 1,
#  '之民數': 1,
#  '微垣': 1,
#  '想漢': 1,
#  '當解': 1,
#  '倘若': 1,
#  '殺伐': 1,
#  '國難': 2,
#  '乘釁': 1,
#  '捕捉': 1,
#  '利忘義之輩': 1,
#  '旗杆': 1,
#  '露穎': 1,
#  '天之怒': 1,
#  '河廝': 1,
#  '能安之者': 2,
#  '子女': 1,
#  '設宴': 3,
#  '雋見': 1,
#  '放過': 1,
#  '越辭': 1,
#  '自領': 2,
#  '富戶': 2,
#  '襄之': 1,
#  '伏于山': 2,
#  '劉虞表奏': 1,
#  '小宴': 1,
#  '家人': 2,
#  '離十': 1,
#  '插旗頭': 1,
#  '五百': 13,
#  '行事': 1,
#  '富家': 1,
#  '之兵': 2,
#  '皇天': 4,
#  '報越': 1,
#  '再休': 1,
#  '卓笑': 4,
#  '因見': 2,
#  '引入': 1,
#  '不飛': 1,
#  '飛入': 1,
#  '文台': 5,
#  '汝言正': 1,
#  '遠望': 2,
#  '名匡': 1,
#  '與親': 1,
#  '山布陣': 1,
#  '筵上': 2,
#  '孫瓚': 1,
#  '子孫': 1,
#  '官驚問': 1,
#  '登龍位': 1,
#  '進恐': 1,
#  '大潰': 2,
#  '急救': 2,
#  '拖刀': 1,
#  '威名': 3,
#  '潛入': 1,
#  '水陸': 1,
#  '李儒出': 1,
#  '關下': 2,
#  '肅曰': 17,
#  '問罪': 2,
#  '轉騎': 1,
#  '富貴': 2,
#  '立陳留': 2,
#  '私匿': 1,
#  '遮天': 1,
#  '劉陶徑': 1,
#  '深處謂': 1,
#  '如入': 2,
#  '內省': 1,
#  '牽過': 1,
#  '同郡': 1,
#  '惟將': 1,
#  '山崩': 1,
#  '祭告': 1,
#  '痛打': 1,
#  '寡不勝': 1,
#  '郡守': 2,
#  '知事': 3,
#  '下樓': 2,
#  '許昌並': 1,
#  '只是': 2,
#  '至嘉德': 1,
#  '喜拜謝': 1,
#  '何太后': 10,
#  '將治': 1,
#  '眼睛': 1,
#  '墮車': 1,
#  '布拔': 1,
#  '早定': 1,
#  '娘娘': 4,
#  '言公鴆殺': 1,
#  '送糧': 1,
#  '正說': 2,
#  '突不入': 1,
#  '流言': 2,
#  '跪謝': 1,
#  '洪脫': 1,
#  '允急止': 1,
#  '變色': 1,
#  '青衣': 1,
#  '昏霧': 1,
#  '下馬': 6,
#  '至死': 2,
#  '碎玉': 1,
#  '方今': 1,
#  '須聽': 1,
#  '願足': 1,
#  '入堂': 1,
#  '城內': 1,
#  '往喚': 1,
#  '允到': 2,
#  '義報': 1,
#  '屯雨集': 1,
#  '報仇': 6,
#  '北部': 2,
#  '布勒': 1,
#  '天命': 1,
#  '因桓帝': 1,
#  '張寶驅兵': 1,
#  '居喪': 1,
#  '健將': 1,
#  '備結義': 1,
#  '第十回': 1,
#  '重兵': 1,
#  '哀號': 1,
#  '他人': 1,
#  '汝勿': 3,
#  '丈八點': 1,
#  '七寶嵌飾': 1,
#  '居民': 1,
#  '青青': 1,
#  '差別': 1,
#  '其面': 1,
#  ...}

# %%
articlelist = sorted(articleDict.items(),key = lambda x:x[1], reverse = True) # 对词典中的词排序

# %%
# 输出词频的前N个
for i in range(100):
    print(articlelist[i])
# Out:
# ('董卓', 97)
# ('呂布', 60)
# ('袁紹', 57)
# ('天下', 53)
# ('玄德', 48)
# ('貂蟬', 37)
# ('太守', 36)
# ('朝廷', 32)
# ('不可', 31)
# ('孫堅', 31)
# ('次日', 26)
# ('李儒', 25)
# ('商議', 25)
# ('引兵', 25)
# ('天子', 24)
# ('左右', 23)
# ('太師', 22)
# ('玄德曰', 22)
# ('大喜', 21)
# ('校尉', 21)
# ('軍士', 21)
# ('今日', 21)
# ('太后', 20)
# ('王允', 20)
# ('何進', 20)
# ('二人', 19)
# ('司徒', 18)
# ('不能', 18)
# ('郭汜', 18)
# ('諸侯', 18)
# ('公孫瓚', 18)
# ('肅曰', 17)
# ('何人', 17)
# ('朱雋', 17)
# ('百姓', 17)
# ('如此', 17)
# ('盧植', 17)
# ('軍馬', 17)
# ('張濟', 16)
# ('百官', 16)
# ('李肅', 16)
# ('張角', 15)
# ('文醜', 15)
# ('皇甫嵩', 15)
# ('大事', 15)
# ('張飛', 15)
# ('如何', 15)
# ('何故', 15)
# ('留王', 15)
# ('只見', 14)
# ('此人', 14)
# ('正是', 14)
# ('冀州', 14)
# ('劉表', 14)
# ('因此', 14)
# ('刺史', 14)
# ('張梁', 14)
# ('袁術', 14)
# ('五百', 13)
# ('將軍', 13)
# ('英雄', 13)
# ('五千', 13)
# ('是夜', 13)
# ('不得', 13)
# ('樊稠', 13)
# ('曹嵩', 13)
# ('不到', 13)
# ('性命', 12)
# ('人馬', 12)
# ('華雄', 12)
# ('李蒙', 12)
# ('叔父', 11)
# ('社稷', 11)
# ('一人', 11)
# ('一日', 11)
# ('星夜', 11)
# ('主公', 11)
# ('相府', 11)
# ('蔡瑁', 11)
# ('趕來', 11)
# ('大臣', 11)
# ('丞相', 11)
# ('三十', 11)
# ('張讓', 11)
# ('何太后', 10)
# ('三人', 10)
# ('分解', 10)
# ('下文', 10)
# ('不見', 10)
# ('乘勢', 10)
# ('問曰', 10)
# ('不知', 10)
# ('相見', 10)
# ('只得', 10)
# ('大呼', 10)
# ('一面', 10)
# ('再拜', 10)
# ('中郎將', 10)
# ('不敢', 10)
# ('忽見', 10)
